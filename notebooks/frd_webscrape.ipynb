# %%
import options_wizard as ow

# %%
from dotenv import load_dotenv
from typing import Set, Deque, Tuple, Optional
from dataclasses import dataclass
from collections import deque, defaultdict, Counter
import html as html_lib
import re
from urllib.request import Request, urlopen
from datetime import datetime, date
import os

load_dotenv()
frd_names = os.getenv("FRD_NAMES")
print(frd_names)

# NOTE: requires `ow` (options_wizard) to be imported/available in your runtime.
# Example:
# import options_wizard as ow

@dataclass
class FrdName:
    tick: str
    name: str
    start_date: ow.DateObj


# ---------- Filters / Normalizers ----------

FUND_LIKE_RE = re.compile(
    r"(?i)\b("
    r"etf|etn|mutual fund|fund\b|index\b|closed[- ]end|exchange[- ]traded|"
    r"i?shares|spdr|vanguard|invesco|proshares|direxion|wisdomtree|"
    r"first trust|guggenheim|nuveen|blackrock|pimco|van eck|"
    r"portfolio|portfo\b|income fund|dividend fund|term fund|"
    r"ucits|sicav|tracker|notes?\b"
    r")\b"
)

NAME_DROP = {
    "the", "and", "of", "by", "for", "a", "an",
    "inc", "incorporated", "corp", "corporation", "co", "company", "companies",
    "ltd", "limited", "llc", "plc", "lp", "llp",
    "cos", "cos.", "co.", "inc.", "ltd.", "plc.",
    "group", "holdings", "holding", "partners", "trust", "reit",
    "real", "estate", "realty", "finance", "financial",
}
NAME_DROP |= {"de", "us", "the"}

TICK_IGNORE = [
    "US", "HK", "LN", "DE", "SW", "VI", "PA", "FRA", "TO", "CN", "KS",
    "MU", "OL", "SS", "BE", "AX", "MI", "NZ", "CO", "SA", "AU"
]

PHRASE_STRIP = [
    r"common shares(?: of beneficial interest)?",
    r"ordinary shares",
    r"american depositary shares",
    r"ads each representing.*",
    r"each representing.*",
    r"common units(?: representing.*)?",
    r"units representing.*",
    r"of beneficial interest",
    r"beneficial interest",
    r"depositary shares",
    r"parent inc.*",
    r"inc\/the|co\/the|group\/the",
    r"\bcmn\b",
    r"\bcom\b",
    r"\bcomm\b",
    r"\bcommon\b",
    r"\bordinary\b",
    r"\bshares?\b",
    r"\bholdings?\b",
    r"\binc\b|\bcorp\b|\bplc\b|\bltd\b|\bllc\b",
    r"\binc\/the\b|\bcorp\/the\b|\bco\/the\b|\bgroup\/the\b",
    r"\bcorp\/de\b|\binc\/de\b",
]

def is_primary_ipo(row) -> bool:
    offer_type = (row.get("Offer Type") or "").lower()

    if "ipo" not in offer_type:
        return False
    if "spac" in offer_type:
        return False
    if "primary" not in offer_type:
        return False

    bad = ["follow-on", "secondary", "block trade", "accelerated", "atm", "rights", "convertible"]
    if any(b in offer_type for b in bad):
        return False

    return True


def extract_pattern(tick_str: str, name_str: str) -> Tuple[str, str]:
    """Normalize ticker/name patterns for matching."""

    def norm_ticker(s: str) -> str:
        s = (s or "").strip()
        s = re.sub(r"(?i)\bclass\b.*$", "", s).strip()

        tick_re = rf'(?i)(?<=\s)(?:{"|".join(map(re.escape, TICK_IGNORE))})\b'
        s = re.sub(tick_re, "", s)

        s = re.sub(r"(?i)(?<=\S)-DELISTED\b", "", s, count=1)
        s = re.sub(r"\s{2,}", " ", s).strip()
        return s.lower()

    def norm_name(s: str) -> str:
        s = (s or "").strip()
        s = re.sub(r"(?i)\bclass\b.*$", "", s).strip()

        if PHRASE_STRIP:
            s = re.sub(r"(?i)\b(?:%s)\b" % "|".join(PHRASE_STRIP), "", s).strip()

        s = s.replace("&", " and ")
        s = re.sub(r"[’']", "", s)
        s = re.sub(r"[^A-Za-z0-9]+", " ", s)
        s = re.sub(r"\s{2,}", " ", s).strip().lower()

        tokens = [t for t in s.split() if t and t not in NAME_DROP]

        CORE_N = 5
        return " ".join(tokens[:CORE_N])

    return norm_ticker(tick_str), norm_name(name_str)


# ---------- IPO Loader (primary IPO only + dedupe per issuer) ----------

def _parse_date_any(s: str):
    s = (s or "").strip()
    if not s:
        return None
    for fmt in ("%d/%m/%Y", "%Y-%m-%d"):
        try:
            return datetime.strptime(s, fmt).date()
        except ValueError:
            pass
    return None

def _best_row_date(row):
    return (_parse_date_any(row.get("Pricing Date"))
            or _parse_date_any(row.get("Announced Date"))
            or _parse_date_any(row.get("Expected Pricing Date")))

def _issuer_key(row) -> str:
    name = (row.get("Issuer Name") or "").lower()
    name = re.sub(r"[^a-z0-9]+", " ", name).strip()
    name = re.sub(
        r"\b(inc|incorporated|corp|corporation|co|company|companies|"
        r"ltd|limited|llc|plc|lp|llp|holdings|holding|group)\b",
        "",
        name,
    )
    name = re.sub(r"\s{2,}", " ", name).strip()
    return name

def load_raw(_dict: bool = False):
    import csv
    load_dotenv()
    names = os.getenv("IPO_NAMES")

    total_count = 0
    skipped_spac = 0
    skipped_non_primary = 0
    skipped_fundlike = 0

    rows = []
    with open(names, "r", encoding="utf-8-sig", newline="") as f:
        reader = csv.DictReader(f)
        for row in reader:
            total_count += 1

            offer_type = row.get("Offer Type", "")
            if "SPAC" in offer_type:
                skipped_spac += 1
                continue

            if not is_primary_ipo(row):
                skipped_non_primary += 1
                continue

            if FUND_LIKE_RE.search(row.get("Issuer Name", "") or ""):
                skipped_fundlike += 1
                continue

            rows.append(row)

    best_by_issuer = {}
    dupes_removed = 0
    for row in rows:
        k = _issuer_key(row)
        d = _best_row_date(row)

        if k not in best_by_issuer:
            best_by_issuer[k] = row
        else:
            dupes_removed += 1
            existing = best_by_issuer[k]
            de = _best_row_date(existing)

            if de is None or (d is not None and d < de):
                best_by_issuer[k] = row

    rows = list(best_by_issuer.values())

    if not _dict:
        tick_patterns = set()
        name_patterns = set()
        for row in rows:
            tick_str = (row.get("Issuer Ticker") or "").strip()
            name_str = (row.get("Issuer Name") or "").strip()
            tick_pattern, name_pattern = extract_pattern(tick_str, name_str)
            if tick_pattern:
                tick_patterns.add(tick_pattern)
            if name_pattern:
                name_patterns.add(name_pattern)
    else:
        tick_patterns = defaultdict(list)
        name_patterns = defaultdict(list)
        for row in rows:
            tick_str = (row.get("Issuer Ticker") or "").strip()
            name_str = (row.get("Issuer Name") or "").strip()
            tick_pattern, name_pattern = extract_pattern(tick_str, name_str)
            if tick_pattern:
                tick_patterns[tick_pattern].append(row)
            if name_pattern:
                name_patterns[name_pattern].append(row)

    print(
        f"Loaded {total_count} rows -> kept {len(rows)} unique primary IPO issuers; "
        f"skipped {skipped_spac} SPACs, {skipped_non_primary} non-primary IPOs, "
        f"skipped {skipped_fundlike} fund-like, removed {dupes_removed} duplicate issuer rows."
    )
    return tick_patterns, name_patterns


# ---------- Safe ticker fallback helpers ----------

def _ipo_date(row) -> Optional[date]:
    return _best_row_date(row)

def build_ticker_candidates():
    """ticker_key -> list of IPO rows (may be >1 if collisions)"""
    tick_map, _ = load_raw(_dict=True)
    return tick_map

def choose_ticker_candidate(
    rows,
    frd_start: date,
    max_before_days: int = 30,
    max_after_days: int = 365,
    ambiguity_days: int = 14,
):
    """
    Choose best IPO row for a ticker given FRD start date.
    Only accept if the best candidate is within the date gate and not ambiguous.
    """
    candidates = []
    for r in rows:
        d = _ipo_date(r)
        if d is None:
            continue
        delta = (frd_start - d).days
        candidates.append((abs(delta), delta, r, d))

    if not candidates:
        return None, "no_candidate_dates"

    candidates.sort(key=lambda x: x[0])
    best_abs, best_delta, best_row, best_d = candidates[0]

    if best_delta < -max_before_days or best_delta > max_after_days:
        return None, f"fails_date_gate(delta_days={best_delta})"

    if len(candidates) >= 2:
        second_abs, second_delta, second_row, second_d = candidates[1]
        if second_abs - best_abs <= ambiguity_days:
            return None, "ambiguous_close_candidates"

    return best_row, f"chosen(delta_days={best_delta})"


# ---------- FRD Scraper (NAME FIRST, SAFE TICKER FALLBACK) ----------

def scrape_names_name_first_safe_ticker() -> Deque[FrdName]:
    """
    Prioritise name matching.
    If name doesn't match, use ticker fallback ONLY when a clearly best IPO candidate exists
    and the FRD start date is close enough to the IPO date.
    """
    if not frd_names:
        raise ValueError("FRD_NAMES env var is not set.")

    req = Request(frd_names, headers={"User-Agent": "Mozilla/5.0"})
    with urlopen(req) as response:
        page = response.read().decode("utf-8", errors="ignore")

    page = re.sub(r"<script[^>]*>.*?</script>", "", page, flags=re.IGNORECASE | re.DOTALL)
    page = re.sub(r"<style[^>]*>.*?</style>", "", page, flags=re.IGNORECASE | re.DOTALL)
    page = re.sub(r"<br\s*/?>", "\n", page, flags=re.IGNORECASE)
    page = re.sub(r"</(p|div|li|tr|td|h\d|ul)>", "\n", page, flags=re.IGNORECASE)
    text = re.sub(r"<[^>]+>", "", page)
    text = html_lib.unescape(text)

    date_cls = getattr(ow, "DateObject", None) or getattr(ow, "DateObj", None)
    if date_cls is None:
        raise AttributeError("options_wizard.DateObj or DateObject not found")

    def parse_date(date_str: str):
        y, m, d = map(int, date_str.split("-"))
        py = date(y, m, d)
        if hasattr(date_cls, "from_iso"):
            return date_cls.from_iso(date_str), py
        return date_cls(y, m, d), py

    targets_ticks, target_names = load_raw()   # sets
    ticker_candidates = build_ticker_candidates()

    date_re = re.compile(r"Start Date:\s*(\d{4}-\d{2}-\d{2})")

    by_name = {}  # dedupe by IPO name key (true "unique")
    skipped_tick_match = deque()
    skipped_name_match = deque()

    # diagnostics
    kept_by_name = 0
    kept_by_safe_ticker = 0
    removed_funds = 0
    removed_nonmatch = 0
    dropped_ticker_no_candidates = 0
    dropped_ticker_date_gate = 0
    dropped_ticker_ambiguous = 0
    total_lines = 0

    for line in text.splitlines():
        total_lines += 1
        if "Start Date" not in line:
            continue

        m = date_re.search(line)
        if not m:
            continue

        date_str = m.group(1)
        prefix = line[:m.start()].strip()
        if not prefix:
            continue

        ticker_raw = prefix.split()[0]

        name_raw = ""
        op = prefix.find("(")
        cp = prefix.rfind(")")
        if op != -1 and cp != -1 and cp > op:
            name_raw = prefix[op + 1:cp].strip()

        # skip FRD fund-like instruments
        if name_raw and FUND_LIKE_RE.search(name_raw):
            removed_funds += 1
            continue

        ticker_key, name_key = extract_pattern(ticker_raw, name_raw)
        ow_date, py_date = parse_date(date_str)

        # your existing diagnostics lists (optional)
        if (ticker_key not in targets_ticks) and (name_key in target_names):
            skipped_name_match.append((ticker_key, name_key))
        if (name_key not in target_names):
            skipped_tick_match.append((ticker_key, name_key))

        # 1) NAME MATCH (priority)
        if name_key in target_names:
            frd = FrdName(tick=ticker_key, name=name_key, start_date=ow_date)
            if frd.name not in by_name or frd.start_date < by_name[frd.name].start_date:
                by_name[frd.name] = frd
            kept_by_name += 1
            continue

        # 2) SAFE TICKER FALLBACK
        if ticker_key in targets_ticks and ticker_key in ticker_candidates:
            chosen_row, reason = choose_ticker_candidate(
                ticker_candidates[ticker_key],
                frd_start=py_date,
                max_before_days=30,
                max_after_days=365,
                ambiguity_days=14,
            )

            if chosen_row is None:
                if reason.startswith("no_candidate"):
                    dropped_ticker_no_candidates += 1
                elif reason.startswith("fails_date_gate"):
                    dropped_ticker_date_gate += 1
                else:
                    dropped_ticker_ambiguous += 1
                removed_nonmatch += 1
                continue

            _, ipo_name_key = extract_pattern(
                chosen_row.get("Issuer Ticker") or "",
                chosen_row.get("Issuer Name") or "",
            )
            if ipo_name_key:
                frd = FrdName(tick=ticker_key, name=ipo_name_key, start_date=ow_date)
                if frd.name not in by_name or frd.start_date < by_name[frd.name].start_date:
                    by_name[frd.name] = frd
                kept_by_safe_ticker += 1
                continue

        removed_nonmatch += 1

    names = deque(by_name.values())

    print("\n===== scrape_names_name_first_safe_ticker() =====")
    print(f"FRD lines total: {total_lines}")
    print(f"kept_by_name: {kept_by_name}")
    print(f"kept_by_safe_ticker: {kept_by_safe_ticker}")
    print(f"removed_funds: {removed_funds}")
    print(f"dropped_ticker_no_candidates: {dropped_ticker_no_candidates}")
    print(f"dropped_ticker_date_gate: {dropped_ticker_date_gate}")
    print(f"dropped_ticker_ambiguous: {dropped_ticker_ambiguous}")
    print(f"removed_nonmatch: {removed_nonmatch}")
    print(f"FINAL unique matched issuers (deduped by IPO name-key): {len(names)}")

    return names, skipped_tick_match, skipped_name_match
# Out:
# https://firstratedata.com/cb/5/complete-us-stocks-index-etf-futures-options

# %%
res, stm, snm = scrape_names_name_first_safe_ticker()
# Out:
# Loaded 6132 rows -> kept 3013 unique primary IPO issuers; skipped 1358 SPACs, 1321 non-primary IPOs, skipped 412 fund-like, removed 28 duplicate issuer rows.
# Loaded 6132 rows -> kept 3013 unique primary IPO issuers; skipped 1358 SPACs, 1321 non-primary IPOs, skipped 412 fund-like, removed 28 duplicate issuer rows.
#
# ===== scrape_names_name_first_safe_ticker() =====
# FRD lines total: 21391
# kept_by_name: 2013
# kept_by_safe_ticker: 230
# removed_funds: 5813
# dropped_ticker_no_candidates: 0
# dropped_ticker_date_gate: 90
# dropped_ticker_ambiguous: 0
# removed_nonmatch: 12789
# FINAL unique matched issuers (deduped by IPO name-key): 2036

# %%
from collections import Counter, defaultdict
from datetime import date

def _fetch_frd_evidence_sets():
    """
    Pull FRD page once and build evidence sets/maps for fast membership tests.
    Returns:
      frd_tickers: set[str] normalized ticker keys seen on FRD Start Date lines
      frd_namekeys: set[str] normalized name keys seen on FRD Start Date lines
      frd_fundlike_namekeys: set[str] name keys whose *FRD raw label* tripped FUND_LIKE_RE
      frd_ticker_to_min_start: dict[str, date] earliest FRD start date per ticker (python date)
    """
    if not frd_names:
        raise ValueError("FRD_NAMES env var is not set.")

    req = Request(frd_names, headers={"User-Agent": "Mozilla/5.0"})
    with urlopen(req) as response:
        page = response.read().decode("utf-8", errors="ignore")

    page = re.sub(r"<script[^>]*>.*?</script>", "", page, flags=re.IGNORECASE | re.DOTALL)
    page = re.sub(r"<style[^>]*>.*?</style>", "", page, flags=re.IGNORECASE | re.DOTALL)
    page = re.sub(r"<br\s*/?>", "\n", page, flags=re.IGNORECASE)
    page = re.sub(r"</(p|div|li|tr|td|h\d|ul)>", "\n", page, flags=re.IGNORECASE)
    text = re.sub(r"<[^>]+>", "", page)
    text = html_lib.unescape(text)

    date_re = re.compile(r"Start Date:\s*(\d{4}-\d{2}-\d{2})")

    frd_tickers = set()
    frd_namekeys = set()
    frd_fundlike_namekeys = set()
    frd_ticker_to_min_start = {}

    for line in text.splitlines():
        if "Start Date" not in line:
            continue
        m = date_re.search(line)
        if not m:
            continue

        date_str = m.group(1)
        y, mo, d = map(int, date_str.split("-"))
        start_py = date(y, mo, d)

        prefix = line[:m.start()].strip()
        if not prefix:
            continue

        ticker_raw = prefix.split()[0]

        name_raw = ""
        op = prefix.find("(")
        cp = prefix.rfind(")")
        if op != -1 and cp != -1 and cp > op:
            name_raw = prefix[op + 1:cp].strip()

        # normalize
        t_key, n_key = extract_pattern(ticker_raw, name_raw)

        if t_key:
            frd_tickers.add(t_key)
            prev = frd_ticker_to_min_start.get(t_key)
            if prev is None or start_py < prev:
                frd_ticker_to_min_start[t_key] = start_py

        if n_key:
            frd_namekeys.add(n_key)
            if name_raw and FUND_LIKE_RE.search(name_raw):
                frd_fundlike_namekeys.add(n_key)

    return frd_tickers, frd_namekeys, frd_fundlike_namekeys, frd_ticker_to_min_start


def explain_missing_by_iterating_ipos(
    max_before_days: int = 30,
    max_after_days: int = 365,
    sample_n: int = 1000,
):
    """
    INVERTED LOGIC:
    Iterate IPO CSV (already filtered/deduped via load_raw(_dict=True)),
    and for each IPO issuer determine if it can be found on FRD.

    Priority:
      1) name-key present on FRD (and not fundlike-filtered)
      2) else ticker present on FRD AND passes date gate vs FRD earliest start date
      3) else missing

    Outputs:
      - prints summary counts
      - returns:
          missing_rows: list of (ticker_key, name_key, raw_name, reason, details)
          counters: Counter of reasons
    """
    # FRD evidence
    frd_tickers, frd_namekeys, frd_fundlike_namekeys, frd_ticker_to_min_start = _fetch_frd_evidence_sets()

    # IPO universe (dict form for easy access to representative rows)
    tick_map, name_map = load_raw(_dict=True)

    ipo_namekeys = list(name_map.keys())  # ~3013
    counters = Counter()
    missing_rows = []

    # For examples per bucket
    examples = defaultdict(list)

    for name_key in ipo_namekeys:
        row = name_map[name_key][0]  # representative row for this issuer-key

        t_raw = (row.get("Issuer Ticker") or "").strip()
        n_raw = (row.get("Issuer Name") or "").strip()
        t_key, nk = extract_pattern(t_raw, n_raw)  # nk should equal name_key usually

        ipo_d = _best_row_date(row)  # python date or None

        # --- 1) Name-key present on FRD ---
        if name_key in frd_namekeys:
            if name_key in frd_fundlike_namekeys:
                counters["present_on_frd_namekey_but_fundlike_filtered"] += 1
                if len(examples["present_on_frd_namekey_but_fundlike_filtered"]) < sample_n:
                    examples["present_on_frd_namekey_but_fundlike_filtered"].append((t_key, name_key, n_raw))
            else:
                counters["found_on_frd_by_namekey"] += 1
            continue

        # --- 2) Ticker present on FRD (date-gated) ---
        if t_key and t_key in frd_tickers:
            frd_start = frd_ticker_to_min_start.get(t_key)

            if ipo_d is None or frd_start is None:
                counters["ticker_on_frd_but_no_date_to_gate"] += 1
                if len(examples["ticker_on_frd_but_no_date_to_gate"]) < sample_n:
                    examples["ticker_on_frd_but_no_date_to_gate"].append((t_key, name_key, n_raw))
                continue

            delta = (frd_start - ipo_d).days
            if delta < -max_before_days or delta > max_after_days:
                counters["ticker_on_frd_but_fails_date_gate_likely_reused"] += 1
                missing_rows.append((t_key, name_key, n_raw, "fails_date_gate", f"delta_days={delta}, frd_start={frd_start}, ipo_date={ipo_d}"))
                if len(examples["ticker_on_frd_but_fails_date_gate_likely_reused"]) < sample_n:
                    examples["ticker_on_frd_but_fails_date_gate_likely_reused"].append((t_key, name_key, n_raw, delta))
            else:
                counters["ticker_on_frd_in_window_but_namekey_missing"] += 1
                missing_rows.append((t_key, name_key, n_raw, "ticker_in_window_name_mismatch", f"delta_days={delta}, frd_start={frd_start}, ipo_date={ipo_d}"))
                if len(examples["ticker_on_frd_in_window_but_namekey_missing"]) < sample_n:
                    examples["ticker_on_frd_in_window_but_namekey_missing"].append((t_key, name_key, n_raw, delta))
            continue

        # --- 3) Not on FRD by name or ticker ---
        counters["not_on_frd_by_name_or_ticker"] += 1
        missing_rows.append((t_key, name_key, n_raw, "not_on_frd", "no_ticker_or_namekey_hit"))
        if len(examples["not_on_frd_by_name_or_ticker"]) < sample_n:
            examples["not_on_frd_by_name_or_ticker"].append((t_key, name_key, n_raw))

    # Print summary
    total = len(ipo_namekeys)
    found = counters["found_on_frd_by_namekey"]
    # Everything else is "not found cleanly by name"
    problematic = total - found

    print("\n===== Inverted check: IPO -> FRD =====")
    print(f"IPO unique issuers (namekeys): {total}")
    print(f"Found on FRD by name-key (clean): {found}")
    print(f"Not found cleanly by name-key (problematic): {problematic}\n")

    print("Breakdown:")
    for k, v in counters.most_common():
        print(f"{k}: {v}")

    # Print a few examples per key bucket
    def show(bucket):
        if bucket not in examples or not examples[bucket]:
            return
        print(f"\n--- Examples: {bucket} (up to {sample_n}) ---")
        for item in examples[bucket]:
            print(item)

    show("not_on_frd_by_name_or_ticker")

    return missing_rows, counters, examples

# Run:
missing_rows, counters, examples = explain_missing_by_iterating_ipos()
# Out:
# Loaded 6132 rows -> kept 3013 unique primary IPO issuers; skipped 1358 SPACs, 1321 non-primary IPOs, skipped 412 fund-like, removed 28 duplicate issuer rows.
#
# ===== Inverted check: IPO -> FRD =====
# IPO unique issuers (namekeys): 3009
# Found on FRD by name-key (clean): 1852
# Not found cleanly by name-key (problematic): 1157
#
# Breakdown:
# found_on_frd_by_namekey: 1852
# not_on_frd_by_name_or_ticker: 864
# ticker_on_frd_in_window_but_namekey_missing: 194
# ticker_on_frd_but_fails_date_gate_likely_reused: 67
# present_on_frd_namekey_but_fundlike_filtered: 32
#
# --- Examples: not_on_frd_by_name_or_ticker (up to 1000) ---
# ('mfbi', 'monroe federal bancorp', 'Monroe Federal Bancorp Inc')
# ('2507', 'cirrus aircraft', 'Cirrus Aircraft Ltd')
# ('tzup', 'thumzup media', 'Thumzup Media Corp')
# ('fadl', 'fadel', 'Fadel Partners Inc')
# ('2310932d', 'aesi', 'AESI Holdings Inc')
# ('cmhf', 'community heritage', 'Community Heritage Financial Inc')
# ('2082549d', 'heartsciences', 'HeartSciences Inc')
# ('mcvt', 'mill city ventures iii', 'Mill City Ventures III Ltd')
# ('vwfb', 'vwf bancorp', 'VWF Bancorp Inc')
# ('9511668d', 'hanover bancorp ny', 'Hanover Bancorp Inc/NY')
# ('2257', 'sirnaomics', 'Sirnaomics Ltd')
# ('gqg', 'gqg', 'GQG Partners Inc')
# ('ebr', 'ebr systems', 'EBR Systems Inc')
# ('npra', 'nepra foods', 'Nepra Foods Inc')
# ('vlcn', 'volcon', 'Volcon Inc')
# ('9990823d', 'century bank', 'US Century Bank')
# ('1905621d', 'biomind research', 'Biomind Research Corp')
# ('llai', 'lunglife ai', 'Lunglife AI Inc')
# ('1911065d', 'datchat', 'DatChat Inc')
# ('nlcp', 'newlake capital md', 'Newlake Capital Partners Inc/MD')
# ('9991006d', 'ambrx biopharma cayman', 'Ambrx Biopharma Cayman Inc')
# ('lgiq', 'logiq', 'Logiq Inc')
# ('bell', 'belluscura', 'Belluscura PLC')
# ('2538060d', 'rain oncology', 'Rain Oncology Inc')
# ('implq', 'ipi legacy liquidation', 'Ipi Legacy Liquidation Co')
# ('aawh', 'ascend wellness', 'Ascend Wellness Holdings Inc')
# ('gwygu', 'gateway garage', 'Gateway Garage Partners LLC')
# ('cdxxu/u', 'choice consolidation', 'Choice Consolidation Corp')
# ('950220', 'neoimmunetech', 'NeoImmuneTech Inc')
# ('agfy', 'agrify', 'Agrify Corp')
# ('1875530d', 'epicquest education inte', 'EpicQuest Education Group Inte')
# ('2148', 'vesync', 'Vesync Co Ltd')
# ('zbt', 'zebit', 'Zebit Inc')
# ('lgcp', 'legion capital', 'Legion Capital Corp')
# ('mhc/u', 'flagship communities', 'Flagship Communities REIT')
# ('atha', 'athira pharma', 'Athira Pharma Inc')
# ('pand', 'pandion therapeutics', 'Pandion Therapeutics Inc')
# ('1855893d', 'safety shot', 'Safety Shot Inc')
# ('polcq', 'polished', 'Polished.com Inc')
# ('950200', 'psomagen', 'Psomagen Inc')
# ('uhu sp', 'united hampshire', 'United Hampshire US REIT')
# ('gwll', 'goldenwell biotech', 'Goldenwell Biotech Inc')
# ('dcsi', 'direct communication solutions', 'Direct Communication Solutions Inc')
# ('1998018d', 'bellring intermediate', 'Bellring Intermediate Holdings')
# ('vie', 'viela bio', 'Viela Bio Inc')
# ('imr', 'imricor medical systems', 'Imricor Medical Systems Inc')
# ('cjax', 'cojax oil gas', 'CoJax Oil and Gas Corp')
# ('lvgo', 'livongo health', 'Livongo Health Inc')
# ('prvl', 'prevail therapeutics', 'Prevail Therapeutics Inc')
# ('1521', 'frontage', 'Frontage Holdings Corp')
# ('lowl', 'lowell farms', 'Lowell Farms Inc')
# ('araus sp', 'acrophyte hospitality', 'Acrophyte Hospitality Trust')
# ('lvce', 'livecare', 'LiveCare Inc')
# ('1855568d', 'avedro', 'Avedro Inc')
# ('gcsh lx', 'gcs', 'GCS Holdings Inc')
# ('nbnd', 'netbrands', 'NetBrands Corp')
# ('rvs', 'revasum', 'Revasum Inc')
# ('flfg', 'federal life', 'Federal Life Group Inc')
# ('2499613d', 'plus products', 'Plus Products Inc')
# ('grtsq', 'gritstone bio', 'Gritstone bio Inc')
# ('prnb', 'principia biopharma', 'Principia Biopharma Inc')
# ('svrs pw', 'silvair', 'Silvair Inc')
# ('eidx', 'eidos therapeutics', 'Eidos Therapeutics Inc')
# ('ps', 'pluralsight', 'Pluralsight Inc')
# ('rgmp', 'regnum', 'Regnum Corp')
# ('wbsr', 'webstar technology', 'Webstar Technology Group Inc')
# ('akom', 'aerkomm', 'Aerkomm Inc')
# ('odtc', 'odonate', 'Odonate Inc')
# ('polx', 'polarean imaging', 'Polarean Imaging PLC')
# ('1337', 'razer', 'Razer Inc')
# ('fsct', 'forescout technologies', 'Forescout Technologies Inc')
# ('950160', 'kolon tissuegene', 'Kolon TissueGene Inc')
# ('ssbp', 'ssb bancorp', 'SSB Bancorp Inc')
# ('rmbl', 'rumbleon', 'RumbleON Inc')
# ('6697 jp', 'techpoint', 'Techpoint Inc')
# ('abwn', 'airborne wireless network', 'Airborne Wireless Network')
# ('lfin', 'longfin', 'Longfin Corp')
# ('vivc', 'vivic', 'Vivic Corp')
# ('naov', 'nanovibronix', 'NanoVibronix Inc')
# ('8989898d', 'ffbw wisconsin', 'FFBW Inc/Wisconsin')
# ('asa no', 'atlantic sapphire asa', 'Atlantic Sapphire ASA')
# ('tntrq', 'tintri', 'Tintri Inc')
# ('akca', 'akcea therapeutics', 'Akcea Therapeutics Inc')
# ('qnta', 'quanta', 'Quanta Inc')
# ('9966911d', 'cadence bancorp', 'Cadence BanCorp')
# ('vsbc', 'vitaspring biomedical', 'VitaSpring Biomedical Co Ltd')
# ('diah', 'diamond', 'Diamond Holdings Inc')
# ('nbevq', 'newage', 'NewAge Inc')
# ('bomh', 'boomer', 'Boomer Holdings Inc')
# ('2462345d', 'wildhorse resource development', 'WildHorse Resource Development Corp')
# ('wuyi', 'china wuyi mountain', 'China WuYi Mountain Ltd')
# ('gsw', 'getswift', 'GetSwift Ltd')
# ('rsls', 'reshape lifesciences', 'ReShape Lifesciences Inc')
# ('950140', 'englewood lab', 'Englewood Lab LLC')
# ('novnq', 'nvn liquidation', 'NVN Liquidation Inc')
# ('lrdg', 'lord global', 'Lord Global Corp')
# ('ento', 'entero therapeutics', 'Entero Therapeutics Inc')
# ('tpic', 'tpi composites', 'TPI Composites Inc')
# ('1448759d', 'ottawa savings bancorp', 'Ottawa Savings Bancorp Inc')
# ('1766050d', 'paragon commercial', 'Paragon Commercial Corp')
# ('mbvxq', 'mabvax therapeutics', 'MabVax Therapeutics Holdings Inc')
# ('ivq/u', 'invesque', 'Invesque Inc')
# ('pzrxq', 'phaserx', 'PhaseRx Inc')
# ('lbcc', 'long blockchain', 'Long Blockchain Corp')
# ('ttez', '3am technologies', '3am Technologies Inc')
# ('vfrm', 'veritas farms', 'Veritas Farms Inc')
# ('btht', 'best hometown bancorp', 'Best Hometown Bancorp Inc')
# ('gttl', 'getelman', 'Getelman Corp')
# ('chmx', 'next chemx', 'Next-ChemX Corp')
# ('adhg', 'ando', 'Ando Holdings Ltd')
# ('2393707d', 'audentes therapeutics', 'Audentes Therapeutics Inc')
# ('ggo/c', 'gabelli go anywhere', 'Gabelli Go Anywhere Trust/The')
# ('isgn', 'isign solutions', 'iSign Solutions Inc')
# ('upd', 'updater', 'Updater Inc')
# ('biq', 'buildingiq', 'BuildingIQ Inc')
# ('1812209d', 'match old', 'Match Group Inc/old')
# ('xcomq', 'xtera communications', 'Xtera Communications Inc')
# ('rven', 'reven housing', 'Reven Housing REIT Inc')
# ('myok', 'myokardia', 'MyoKardia Inc')
# ('cfdb', 'central federal bancshares', 'Central Federal Bancshares Inc')
# ('ara', 'american renal associates', 'American Renal Associates Holdings Inc')
# ('elio', 'elio motors', 'Elio Motors Inc')
# ('adsw', 'advanced disposal services', 'Advanced Disposal Services Inc')
# ('coynq', 'copsync', 'Copsync Inc')
# ('fifg', 'first foods', 'First Foods Group Inc')
# ('cura', 'curaleaf', 'Curaleaf Holdings Inc')
# ('aimt', 'aimmune therapeutics', 'Aimmune Therapeutics Inc')
# ('cnfr', 'conifer', 'Conifer Holdings Inc')
# ('nwbb', 'new bancorp', 'New Bancorp Inc')
# ('2512660d', 'mindbody', 'MINDBODY Inc')
# ('1901980d', 'airxpanders', 'AirXpanders Inc')
# ('1865332d', 'terraform global', 'TerraForm Global Inc')
# ('1940857d', 'fogo chao', 'Fogo De Chao Inc')
# ('tmbrq', 'trex wind down', 'Trex Wind Down Inc')
# ('cdrbq', 'code rebel', 'Code Rebel Corp')
# ('qlgn', 'qualigen therapeutics', 'Qualigen Therapeutics Inc')
# ('9994567d', 'provident bancorp ma', 'Provident Bancorp Inc/MA')
# ('1237376d', 'fortuneswell', 'Fortuneswell Corp')
# ('coti', 'coretag', 'Coretag Inc')
# ('team no', 'team tankers international', 'Team Tankers International Ltd')
# ('gcty', 'gain cities', 'Gain Cities Ltd')
# ('fsb', 'franklin network', 'Franklin Financial Network Inc')
# ('tdxp', 'global smart capital', 'Global Smart Capital Corp')
# ('slrx', 'salarius pharmaceuticals', 'Salarius Pharmaceuticals Inc')
# ('pdro', 'pedros list', "Pedro's List Inc")
# ('amct', 'american education center', 'American Education Center Inc')
# ('owpc', 'one world products', 'One World Products Inc')
# ('naex', 'national art exchange', 'National Art Exchange Inc')
# ('mrge', 'mirage energy', 'Mirage Energy Corp')
# ('appb', 'applied biosciences', 'Applied Biosciences Corp')
# ('fgen', 'fibrogen', 'FibroGen Inc')
# ('sntw', 'summit networks', 'Summit Networks Inc')
# ('9876123d', 'hess midstream operations', 'Hess Midstream Operations LP')
# ('awsn', 'asn technologies', 'ASN Technologies Inc')
# ('eygy', 'enterprise energy', 'Enterprise Energy Inc')
# ('mbcq', 'mb bancorp', 'MB Bancorp Inc')
# ('mpvr', 'mp ventures', 'MP Ventures Inc')
# ('fsam', 'fifth street asset management', 'Fifth Street Asset Management Inc')
# ('mdvxu', 'innoveren scientific', 'Innoveren Scientific Inc')
# ('frtg', 'frontera', 'Frontera Group Inc')
# ('1934798d', 'dermira', 'Dermira Inc')
# ('wewa', 'wewards', 'Wewards Inc')
# ('blcs', 'blockchain solutions', 'Blockchain Solutions Inc')
# ('bmxc', 'bemax', 'Bemax Inc')
# ('stal', 'star alliance international', 'Star Alliance International Corp')
# ('eltz', 'elite', 'Elite Group Inc')
# ('pfnx', 'pfenex', 'Pfenex Inc')
# ('ptco', 'petrogas', 'PetroGas Co')
# ('terp', 'terraform power', 'TerraForm Power Inc')
# ('vry', 'petro victory energy', 'Petro-Victory Energy Corp')
# ('ngld', 'nevada canyon gold', 'Nevada Canyon Gold Corp')
# ('cwrv', 'clearwater ventures', 'Clearwater Ventures Inc')
# ('mobl', 'mobileiron', 'MobileIron Inc')
# ('hmpq', 'hempamericana', 'HempAmericana Inc')
# ('1851869d', 'dominion energy midstream', 'Dominion Energy Midstream Partners LP')
# ('mmeg', 'momentous entertainment', 'Momentous Entertainment Group Inc')
# ('gbim', 'globeimmune', 'GlobeImmune Inc')
# ('plrm', 'pilgrim bancshares', 'Pilgrim Bancshares Inc')
# ('medr', 'medresponse', 'Medresponse Corp')
# ('renb', 'renovaro', 'Renovaro Inc')
# ('1918511d', 'aerohive networks', 'Aerohive Networks Inc')
# ('gnid', 'genesys id', 'GeneSYS ID Inc')
# ('sply', 'socialplay usa', 'SocialPlay USA Inc')
# ('imgl', 'image international', 'Image International Group Inc')
# ('nugn', 'nugene international', 'NuGene International Inc')
# ('pkayq', 'peekay boutiques', 'Peekay Boutiques Inc')
# ('hwis', 'home bancorp wisconsin', 'Home Bancorp Wisconsin Inc')
# ('sncf', 'sanarco funds', 'Sanarco Funds Inc')
# ('qbio', 'q biomed', 'Q BioMed Inc')
# ('9991028d', 'fg delawar', 'FG Financial Group Inc/Delawar')
# ('gwsn', 'gulf west security network', 'Gulf West Security Network Inc')
# ('csaxq', 'csa', 'CSA Holdings Inc')
# ('4589 jp', 'acucela', 'Acucela Inc')
# ('tlcc', 'twinlab consolidated', 'Twinlab Consolidated Holdings Inc')
# ('ipsi', 'innovative payment solutions', 'Innovative Payment Solutions Inc')
# ('pmhg', 'prime meridian', 'Prime Meridian Holding Co')
# ('itdp', 'instride', 'Instride Inc')
# ('asnt', 'arias intel', 'Arias Intel Corp')
# ('skkb', 'stark naked bobbers', 'Stark Naked Bobbers')
# ('ornt', 'ournett', 'Ournett Holdings Inc')
# ('blyq', 'bally', 'Bally Corp')
# ('celpq', 'cypress environmental', 'Cypress Environmental Partners')
# ('hloc', 'helo', 'Helo Corp')
# ('tlog', 'tetralogic pharmaceuticals', 'TetraLogic Pharmaceuticals Corp')
# ('anfrl', 'fantex', 'Fantex Inc')
# ('egltq', 'zyla life sciences', 'Zyla Life Sciences')
# ('mydx', 'mydx', 'MyDx Inc')
# ('jgweq', 'jg wentworth', 'JG Wentworth Co/The')
# ('mrlb', 'miramar labs', 'Miramar Labs Inc')
# ('cuda', 'barracuda networks', 'Barracuda Networks Inc')
# ('rreo', 'resource opportunity ii', 'Resource Real Estate Opportunity REIT II Inc')
# ('eigi', 'endurance international', 'Endurance International Group Holdings Inc')
# ('2011654d', 'globalwafers singapore pte', 'Globalwafers Singapore Pte Ltd')
# ('2463165d', 'fidelity guaranty life', 'Fidelity & Guaranty Life')
# ('vmemq', 'violin memory federal systems', 'Violin Memory Federal Systems Inc')
# ('lfer', 'life on earth', 'Life on Earth Inc')
# ('ssgc', 'safespace global', 'SafeSpace Global Corp')
# ('2521604d', 'content checked', 'Content Checked Holdings Inc')
# ('gtic', 'greentech innovations', 'GreenTech Innovations Inc')
# ('pdrg', 'phillips edison grocery center ii', 'Phillips Edison Grocery Center REIT II Inc')
# ('bindq', 'dnib unwind', 'DNIB Unwind Inc')
# ('swee', 'sweegen', 'SweeGen Inc')
# ('plfx', 'pulse evolution', 'Pulse Evolution Corp')
# ('vrvr', 'virtual interactive technologies', 'Virtual Interactive Technologies Corp')
# ('chgt', 'changing technologies', 'Changing Technologies Inc')
# ('fprx', 'five prime therapeutics', 'Five Prime Therapeutics Inc')
# ('azurq', 'azure midstream', 'Azure Midstream Partners LP')
# ('sfxeq', 'livestyle', 'LiveStyle Inc')
# ('prki', 'perk international', 'Perk International Inc')
# ('1316', 'nexteer automotive', 'Nexteer Automotive Group Ltd')
# ('vxbt', 'vortex blockchain technologies', 'Vortex Blockchain Technologies Inc')
# ('1469138d', 'envision healthcare', 'Envision Healthcare Holdings Inc')
# ('joneq', 'jones energy', 'Jones Energy Inc')
# ('0813202d', 'cosmo ventures', 'Cosmo Ventures Inc')
# ('2392595d', 'physicians', 'Physicians Realty Trust')
# ('blgi', 'blgi', 'BLGI Inc')
# ('rcapq', 'aretec', 'Aretec Group Inc')
# ('mwrx', 'mergeworthrx', 'MergeWorthRx Corp')
# ('vibi', 'vilacto bio', 'Vilacto Bio Inc')
# ('riii', 'renavotio', 'Renavotio Inc')
# ('gvbt', 'green vision biotechnology', 'Green Vision Biotechnology Corp')
# ('fxer', 'first xeris', 'First Xeris Corp')
# ('hds', 'hd supply', 'HD Supply Holdings Inc')
# ('ptla', 'portola pharmaceuticals', 'Portola Pharmaceuticals Inc')
# ('sbes', 'south beach spirits', 'South Beach Spirits Inc')
# ('1324141d', 'electrical geodesics', 'Electrical Geodesics Inc')
# ('950130', 'access bio', 'Access Bio Inc')
# ('prcx', 'phoenix rising', 'Phoenix Rising Cos')
# ('2260918d', 'vecta', 'Vecta Inc')
# ('opvs', 'nanoflex power', 'NanoFlex Power Corp')
# ('thst', 'truett hurst', 'Truett-Hurst Inc')
# ('clcs', 'cell source', 'Cell Source Inc')
# ('2227595d', 'ambit biosciences', 'Ambit Biosciences Corp')
# ('benh', 'bio en', 'Bio-En Holdings Corp')
# ('cqcq', 'makingorg', 'MakingORG Inc')
# ('9966699d', 'pnmac', 'PNMAC Holdings Inc')
# ('appg', 'apptigo international', 'Apptigo International Inc')
# ('ooil', 'perkins oil gas', 'Perkins Oil & Gas Inc')
# ('loli', 'lollipop', 'Lollipop Corp')
# ('sset', 'starstream entertainment', 'Starstream Entertainment Inc')
# ('1023765d', 'connectone bancorp old', 'ConnectOne Bancorp Inc/Old')
# ('arat', 'arax', 'Arax Holdings Corp')
# ('enumq', 'enumeral biomedical', 'Enumeral Biomedical Holdings Inc')
# ('hbpe', 'hbp energy', 'HBP Energy Corp')
# ('nslpq', 'new source energy', 'New Source Energy Partners LP')
# ('sprz', 'spriza', 'Spriza Inc')
# ('bfyt', 'benefytt technologies', 'Benefytt Technologies LLC')
# ('omgb', 'omega brands', 'Omega Brands Inc')
# ('bpol', 'blackpoll fleet international', 'BlackPoll Fleet International Inc')
# ('shrk', 'sharkreach', 'SharkReach Inc')
# ('immg', 'immage biotherapeutics', 'Immage Biotherapeutics Corp')
# ('gpne', 'next graphite', 'Next Graphite Inc')
# ('tcai', 'aimtc', 'AIMTC Inc')
# ('rmri', 'rocky mountain industrials', 'Rocky Mountain Industrials Inc')
# ('leai', 'legacy education alliance', 'Legacy Education Alliance Inc')
# ('cgrt', 'corgreen technologies', 'CorGreen Technologies Holding Corp')
# ('elrn', 'greenwood hall', 'Greenwood Hall Inc')
# ('tsts', 'that marketing solution', 'That Marketing Solution Inc')
# ('avgc', 'avangard capital', 'Avangard Capital Group Inc')
# ('1868223d', 'ignyta', 'Ignyta Inc')
# ('lifs', 'life stem genetics', 'Life Stem Genetics Inc')
# ('impc', 'imperial plantation', 'Imperial Plantation Corp')
# ('curm', 'cur media', 'CUR Media Inc')
# ('zeox', 'zeo scientifix', 'Zeo ScientifiX Inc')
# ('cesx', 'ces synergies', 'CES Synergies Inc')
# ('stva', 'stevva', 'Stevva Corp')
# ('itup', 'interups', 'Interups Inc')
# ('cdxq', 'china xiao quan care', 'China De Xiao Quan Care Group')
# ('mjmj', 'maryjane', 'MaryJane Group Inc/The')
# ('sfiv', 'sector 5', 'Sector 5 Inc')
# ('lncoq', 'linnco', 'LinnCo LLC')
# ('wcvc', 'west coast ventures', 'West Coast Ventures Group Corp')
# ('2054244d', 'mobetize', 'Mobetize Corp')
# ('gfox', 'grey fox', 'Grey Fox Holdings Corp')
# ('ctbo', 'cantabio pharmaceuticals', 'Cantabio Pharmaceuticals Inc')
# ('mpvc', 'modern pvc', 'Modern PVC Inc')
# ('blfr', 'bluefire equipment', 'BlueFire Equipment Corp')
# ('crym', 'cryomass technologies', 'Cryomass Technologies Inc')
# ('mcbk', 'madison county', 'Madison County Financial Inc')
# ('norx', 'norstra energy', 'Norstra Energy Inc')
# ('micb', 'microlin bio', 'Microlin Bio Inc')
# ('iten', 'codesmart', 'CodeSmart Holdings Inc')
# ('blck', 'blackcraft cult', 'Blackcraft Cult Inc')
# ('ezrg', 'ezraider', 'EZRaider Co')
# ('blkg', 'black stallion oil gas', 'Black Stallion Oil & Gas Inc')
# ('mtgb', 'meetinghouse bancorp', 'Meetinghouse Bancorp Inc')
# ('svle', 'seville ventures', 'Seville Ventures Corp')
# ('osp', 'osprey medical', 'Osprey Medical Inc')
# ('onfa', 'one 4 art', 'One 4 Art Ltd')
# ('ubiq', 'ubiquity', 'Ubiquity Inc')
# ('ngey', 'new global energy', 'New Global Energy Inc')
# ('arthq', 'arch therapeutics', 'Arch Therapeutics Inc')
# ('eqm', 'eqm midstream', 'EQM Midstream Partners LP')
# ('hmst', 'homestreet', 'HomeStreet Inc')
# ('gase', 'gase energy', 'GASE Energy Inc')
# ('pgsc', 'progressive green solutions', 'Progressive Green Solutions Inc')
# ('etst', 'earth science tech', 'Earth Science Tech Inc')
# ('puge', 'puget technologies', 'Puget Technologies Inc')
# ('xtls', 'xstelos', 'Xstelos Holdings Inc')
# ('jemc', 'jem capital', 'JEM Capital Inc')
# ('avth', 'av therapeutics', 'AV Therapeutics Inc')
# ('awaw', 'white fox ventures', 'White Fox Ventures Inc')
# ('drnk', 'noho', 'NoHo Inc')
# ('prre', 'praetorian property', 'Praetorian Property Inc')
# ('wycc', 'worry free', 'Worry Free Holdings Co')
# ('svte', 'service team', 'Service Team Inc')
# ('cxi', 'currency exchange international', 'Currency Exchange International Corp')
# ('1648416d', 'exacttarget', 'ExactTarget LLC')
# ('1816375d', 'caesars', 'Caesars Holdings Inc')
# ('ajac', 'aja cannafacturing', 'Aja Cannafacturing Inc')
# ('nyca', 'nycamedia', 'nycaMedia Inc')
# ('chmr', 'chimera energy', 'Chimera Energy Corp')
# ('vbi/h', 'vivione biosciences', 'Vivione Biosciences Inc')
# ('wein', 'west end indiana bancshares', 'West End Indiana Bancshares Inc')
# ('chno', 'classworx', 'ClassWorx Inc')
# ('ggg/h', 'g6 materials', 'G6 Materials Corp')
# ('1119666d', 'james river', 'James River Group Inc')
# ('hznm', 'horizon minerals', 'Horizon Minerals Corp')
# ('atoa', 'altovida', 'Altovida Inc')
# ('anpl', 'anpulo food development', 'Anpulo Food Development Inc')
# ('sfpi', 'santa fe petroleum', 'Santa Fe Petroleum Inc')
# ('snecq', 'mesquite energy', 'Mesquite Energy Inc')
# ('slnn', 'saleen automotive', 'Saleen Automotive Inc')
# ('ifm', 'infrastructure materials', 'Infrastructure Materials Corp')
# ('lbtd', 'lotus bio technology development', 'Lotus Bio-Technology Development Corp')
# ('arvm', 'mirage capital', 'Mirage Capital Corp')
# ('ahi/h', 'agility health', 'Agility Health Inc')
# ('gid', 'gi dynamics', 'GI Dynamics Inc')
# ('1703104d', 'mycelx technologies', 'Mycelx Technologies Corp')
# ('nddg', 'nudg media', 'Nudg Media Inc')
# ('esch', 'escher', 'Escher Group Holdings PLC')
# ('polr', 'polar petroleum', 'Polar Petroleum Corp')
# ('slnr', 'sealand natural resources', 'Sealand Natural Resources Inc')
# ('gsehq', 'gse', 'GSE Holding Inc')
# ('snnc', 'sibannac', 'Sibannac Inc')
# ('pscr', 'proto script pharmaceutical', 'Proto Script Pharmaceutical Corp')
# ('tbev', 'high performance beverages', 'High Performance Beverages Co')
# ('ayag', 'amaya global', 'Amaya Global Holdings Corp')
# ('mwai', 'medwellai', 'MedWellAI Inc')
# ('sltn', 'silverton energy', 'Silverton Energy Inc')
# ('jidg', 'joymain international development', 'Joymain International Development Group Inc')
# ('tpni', 'pulse network', 'Pulse Network Inc/The')
# ('1818713d', 'ceres', 'Ceres Inc')
# ('umax', 'umax', 'Umax Group Corp')
# ('imcl', 'immunoclin', 'Immunoclin Corp')
# ('vngeu', 'graphene solar technologies', 'Graphene & Solar Technologies Ltd')
# ('safc', 'safecode drug technologies', 'SafeCode Drug Technologies Corp')
# ('2129234d', 'lrr energy', 'LRR Energy LP')
# ('vrdr', 'verde resources', 'Verde Resources Inc')
# ('mcpi', 'mansfield martin exploration mining', 'Mansfield-Martin Exploration Mining Inc')
# ('jadg', 'jade global', 'Jade Global Holdings Inc')
# ('ngrp', 'ngen technologies cor', 'Ngen Technologies Holdings Cor')
# ('pbsk', 'poage bankshares', 'Poage Bankshares Inc')
# ('lcdc', 'caliber imaging diagnostics', 'Caliber Imaging & Diagnostics')
# ('tqla', 'montalvo spirits', 'Montalvo Spirits Inc')
# ('isgi', 'international safety', 'International Safety Group Inc')
# ('2407454d', 'neurotrope', 'Neurotrope Inc')
# ('agin', 'american graphite technologies', 'American Graphite Technologies Inc')
# ('8240556z', 'marilynjean interactive', 'MarilynJean Interactive Inc')
# ('pdki', 'pdk energy', 'PDK Energy Inc')
# ('pacdq', 'pacific drilling sa', 'Pacific Drilling SA')
# ('2336146d', 'enterprise terminaling services', 'Enterprise Terminaling Services LP')
# ('wast', 'waste energy', 'Waste Energy Corp')
# ('pmcm', 'primco management', 'Primco Management Inc')
# ('agss', 'ameriguard security services', 'Ameriguard Security Services')
# ('crol', 'carroll bancorp', 'Carroll Bancorp Inc')
# ('evti', 'eventure interactive', 'Eventure Interactive Inc')
# ('sibc', 'state investors bancorp', 'State Investors Bancorp Inc')
# ('2372371d', 'porto energy', 'Porto Energy Corp')
# ('1752683d', 'first connecticut bancorp farmington ct', 'First Connecticut Bancorp Inc/Farmington CT')
# ('2456324d', 'slr senior investment', 'SLR Senior Investment Corp')
# ('vizc', 'vizconnect', 'VizConnect Inc')
# ('rva', 'reva medical', 'REVA Medical Inc')
# ('kyak', 'kayak software', 'KAYAK Software Corp')
# ('lvdw', 'liquidvalue development', 'LiquidValue Development Inc')
# ('1624831d', 'tiaa fsb', 'TIAA FSB Holdings Inc')
# ('bssp', 'reve technologies', 'Reve Technologies Inc')
# ('inlb', 'item 9 labs', 'Item 9 Labs Corp')
# ('nsub', 'new york sub', 'New York Sub Co')
# ('aftn', 'awareness teens', 'Awareness For Teens Inc')
# ('glbr', 'global brokerage', 'Global Brokerage Inc')
# ('emgcq', 'emergent capital', 'Emergent Capital Inc')
# ('cusxq', 'continuityx solutions', 'Continuityx Solutions Inc')
# ('1708781d', 'complete genomics', 'Complete Genomics Inc')
# ('stnd', 'standard avb', 'Standard AVB Financial Corp')
# ('iphi', 'inphi', 'Inphi Corp')
# ('wmgi', 'wright medical nv', 'Wright Medical Group NV')
# ('9876549d', 'nielsen nv', 'Nielsen NV')
# ('sau', 'st augustine gold copper', 'St Augustine Gold and Copper Ltd')
# ('1448479d', 'campus crest communities', 'Campus Crest Communities Inc')
# ('1876917d', 'nupathe', 'NuPathe Inc')
# ('gnf', 'greenfields petroleum', 'Greenfields Petroleum Corp')
# ('smgiu', 'smg industries', 'SMG Industries Inc')
# ('2579681d', 'aeroflex', 'Aeroflex Holding Corp')
# ('empo', 'empowered products', 'Empowered Products Inc')
# ('wmlpq', 'westmoreland resource', 'Westmoreland Resource Partners LP')
# ('fmtb', 'fairmount bancorp', 'Fairmount Bancorp Inc')
# ('gnmk', 'genmark diagnostics', 'GenMark Diagnostics Inc')
# ('900100', 'ameridge', 'Ameridge Corp')
# ('9998522d', 'primo water operations', 'Primo Water Operations Inc')
# ('vltc', 'voltari', 'Voltari Corp')
# ('ise', 'ise', 'ISE Ltd')
# ('verf', 'versailles', 'Versailles Financial Corp')
# ('anth', 'anthera pharmaceuticals', 'Anthera Pharmaceuticals Inc')
# ('hari', 'harvard illinois bancorp', 'Harvard Illinois Bancorp Inc')
# ('mmed', 'midas medici', 'Midas Medici Group Holdings Inc')
# ('1544310d', 'dole food', 'Dole Food Co Inc')
# ('1627503d', 'colony capital old', 'Colony Capital Inc/Old')
# ('pmic', 'penn millers', 'Penn Millers Holding Corp')
# ('2892057z', 'id watchdog', 'ID Watchdog Inc')
# ('2882961z', 'harvest health recreation', 'Harvest Health & Recreation Inc')
# ('hibe', 'hibernia bancorp', 'Hibernia Bancorp Inc')
# ('0852651d', 'metals usa', 'Metals USA Holdings Corp')
# ('1853725d', 'mood media ca', 'Mood Media Corp/CA')
# ('usrm', 'stem cell', 'US Stem Cell Inc')
# ('adis', 'armor designs', 'Armor Designs Inc')
# ('avd/h', 'avidus management', 'Avidus Management Group Inc')
# ('crpu', 'ceres global ag', 'Ceres Global Ag Corp')
# ('hip', 'hipcricket old', 'HipCricket Inc/Old')
# ('jush', 'jushi', 'Jushi Holdings Inc')
# ('9953211d', 'western midstream operating', 'Western Midstream Operating LP')
# ('caz', 'caza oil gas', 'Caza Oil & Gas Inc')
# ('rhieq', 'sonar entertainment', 'Sonar Entertainment Inc')
# ('wmz', 'williams pipeline', 'Williams Pipeline Partners LP')
# ('1416528d', 'cardtronics', 'Cardtronics Inc')
# ('aryx', 'aryx therapeutics', 'ARYx Therapeutics Inc')
# ('7586674q', '3par', '3PAR Inc')
# ('osp', 'osg america', 'OSG America LP')
# ('hffiu', 'u swirl', 'U-Swirl Inc')
# ('1553838d', 'entropic communications', 'Entropic Communications Inc')
# ('2147946d', 'pioneer southwest energy', 'Pioneer Southwest Energy Partners LP')
# ('qelp', 'quest energy', 'Quest Energy Partners LP')
# ('gigiq', 'gulfstream international', 'Gulfstream International Group Inc')
# ('fabk', 'first advantage bancorp', 'First Advantage Bancorp')
# ('9990616d', 'reshape lifesciences ca', 'ReShape Lifesciences Inc/CA')
# ('1667717d', 'demandtec', 'DemandTec Inc')
# ('pmii', 'power medical interventions', 'Power Medical Interventions Inc')
# ('targ', 'targanta therapeutics', 'Targanta Therapeutics Corp')
# ('rthm', 'rhythmone', 'Rhythmone PLC')
# ('segi', 'sycamore entertainment', 'Sycamore Entertainment Group Inc')
# ('tyr', 'tyratech', 'TyraTech Inc')
# ('vrtu', 'virtusa', 'Virtusa Corp')
# ('sirt', 'sirtris pharmaceuticals', 'Sirtris Pharmaceuticals Inc')
# ('hlcsq', 'helicos biosciences', 'Helicos BioSciences Corp')
# ('0878522d', 'crestwood midstream old', 'Crestwood Midstream Partners LP/Old')
# ('pinn', 'pinnacle gas resources', 'Pinnacle Gas Resources Inc')
# ('gluu', 'glu mobile', 'Glu Mobile Inc')
# ('cnwuf', 'china networks international', 'China Networks International Holdings Ltd')
# ('2060389d', 'fortress investment', 'Fortress Investment Group LLC')
# ('qrr', 'quadra', 'Quadra Realty Trust Inc')
# ('mve/u', 'smart move', 'Smart Move Inc')
# ('dep', 'duncan energy', 'Duncan Energy Partners LP')
# ('vyco', 'vycon', 'Vycon Inc')
# ('1817382d', 'dct industrial', 'DCT Industrial Trust Inc')
# ('foodu', 'vaughan foods', 'Vaughan Foods Inc')
# ('dsupq', 'dayton superior', 'Dayton Superior Corp')
# ('evoq', 'evoq properties', 'EVOQ Properties Inc')
# ('1793654d', 'highland distressed opportunities', 'Highland Distressed Opportunities Inc')
# ('ptmn', 'portman ridge', 'Portman Ridge Finance Corp')
# ('nlst', 'netlist', 'Netlist Inc')
# ('1334197d', 'xtent', 'Xtent Inc')
# ('sola', 'emeren', 'Emeren Group Ltd')
# ('usbe', 'bioenergy', 'US BioEnergy Corp')
# ('vraiu', 'viragen', 'Viragen Inc')
# ('atn', 'atlas energy resources', 'Atlas Energy Resources LLC')
# ('affy', 'affymax', 'Affymax Inc')
# ('ghseq', 'gatehouse media', 'GateHouse Media LLC')
# ('0117799d', 'penn virginia gp', 'Penn Virginia GP Holdings LP')
# ('3551941q', 'hostopia', 'Hostopia.com Inc')
# ('rlm', 'realm therapeutics', 'Realm Therapeutics PLC')
# ('ofsi', 'omni services', 'Omni Financial Services Inc')
# ('8161730q', 'newwest gold', 'NewWest Gold Corp')
# ('trbn', 'trubion pharmaceuticals', 'Trubion Pharmaceuticals Inc')
# ('hpgp', 'hiland gp', 'Hiland Holdings GP LP')
# ('seno', 'senorx', 'SenoRx LLC')
# ('1650928d', 'chicopee bancorp', 'Chicopee Bancorp Inc')
# ('pflm', 'powerfilm', 'PowerFilm Inc')
# ('evepq', 'ev energy', 'EV Energy Partners LP')
# ('bbepq', 'breitburn energy', 'Breitburn Energy Partners LP')
# ('arteq', 'artes medical', 'Artes Medical Inc')
# ('1664784d', 'gilead pharmasset', 'Gilead Pharmasset LLC')
# ('rpse', 'research pharmaceutical services', 'ReSearch Pharmaceutical Services Inc')
# ('0618586d', 'buckeye gp', 'Buckeye GP Holdings LP')
# ('trbo', 'turbotec products', 'Turbotec Products Ltd')
# ('amgiu', 'american mold guard', 'American Mold Guard Inc')
# ('brst', 'burst media ma', 'Burst Media LLC/MA')
# ('1413744d', 'golfsmith international', 'Golfsmith International Holdings Inc')
# ('rest', 'restore medical', 'Restore Medical Inc')
# ('nstr', 'northstar neuroscience', 'Northstar Neuroscience Inc')
# ('695510z', 'production enhancement', 'Production Enhancement Group Inc')
# ('bwtrq', 'basin water', 'Basin Water Inc')
# ('9876533d', 'delek energy', 'Delek US Energy Inc')
# ('1240716d', 'targa energy', 'Targa Energy LP')
# ('psid', 'positiveid', 'PositiveID Corp')
# ('cyrv', 'crystal river capital', 'Crystal River Capital Inc')
# ('ncst', 'nucryst pharmaceuticals', 'NUCRYST Pharmaceuticals Corp')
# ('eicu', 'visicu', 'VISICU Inc')
# ('nmls', 'new media lottery services', 'New Media Lottery Services PLC')
# ('mgg', 'magellan midstream', 'Magellan Midstream Holdings LP')
# ('1899843d', 'clayton', 'Clayton Holdings Inc')
# ('dxtrq', 'dextera surgical', 'Dextera Surgical Inc')
# ('atel', 'american telecom services', 'American Telecom Services Inc')
# ('glbm', 'globe specialty metals', 'Globe Specialty Metals Inc')
# ('snbi', 'bbva usa bancshares fort worth', 'BBVA USA Bancshares Inc/Fort Worth TX')
# ('royu', 'royster clark', 'Royster-Clark Ltd')
# ('1455797d', 'tal international', 'TAL International Group Inc')
# ('nuvmu', 'nuvim', 'NuVim Inc')
# ('pyf', 'polyfuel', 'PolyFuel Inc')
# ('tcyf', 'transcommunity', 'TransCommunity Financial Corp')
# ('0212710d', 'k f industries', 'K&F Industries Holdings Inc')
# ('rutx', 'republic', 'Republic Cos Group Inc')
# ('esch', 'eschelon telecom', 'Eschelon Telecom Inc')
# ('avrx', 'avalon pharmaceuticals', 'Avalon Pharmaceuticals Inc')
# ('kidsq', 'parent', 'Parent Co/The')
# ('9893105q', 'enterprise gp', 'Enterprise GP Holdings LP')
# ('clas/h', 'claritas pharmaceuticals', 'Claritas Pharmaceuticals Inc')
# ('swatu', 'pepperball technologies', 'PepperBall Technologies Inc')
# ('coly', 'coley pharmaceutical', 'Coley Pharmaceutical Group Inc')
# ('1280451d', 'auex ventures', 'AuEx Ventures Inc')
# ('8683942q', 'cryocor', 'CryoCor Inc')
# ('icdgu', 'icop digital', 'ICOP Digital Inc')
# ('hem', 'hemosense', 'HemoSense Inc')
# ('0977894d', 'united bancorp old', 'United Financial Bancorp Inc/Old')
# ('fpbi', 'fpb bancorp', 'FPB Bancorp Inc')
# ('frr', 'frontera resources', 'Frontera Resources Corp')
# ('1965472d', 'meadow valley trucking', 'Meadow Valley Trucking Inc')
# ('1409833d', 'columbia equity', 'Columbia Equity Trust Inc')
# ('nrgp', 'crestwood', 'Crestwood Holdings LP')
# ('0216051d', 'new skies satellites', 'New Skies Satellites Holdings US LLC')
# ('npte', 'north pointe', 'North Pointe Holdings Corp')
# ('aurdq', 'accuride old', 'Accuride Corp/Old')
# ('ocfl', 'oc', 'OC Financial Inc')
# ('bfbc', 'benjamin franklin bancorp', 'Benjamin Franklin Bancorp Inc')
# ('anrzq', 'alpha natural resources', 'Alpha Natural Resources Inc')
# ('gkr', 'gatekeeper systems united states', 'Gatekeeper Systems Inc/United States')
# ('0918134d', 'emageon', 'Emageon Inc')
# ('tposq', 'tarpon industries', 'Tarpon Industries Inc')
# ('pprbq', 'prb energy', 'PRB Energy Inc')
# ('yyyh', 'china yanyuan yuhui national e', 'China Yanyuan Yuhui National E')
# ('1395066d', 'hiland', 'Hiland Partners Holdings LLC')
# ('atp', 'atlantic power', 'Atlantic Power Corp')
# ('0000708d', 'spirit old', 'Spirit Finance Corp/Old')
# ('fstf', 'first state fl', 'First State Financial Corp/FL')
# ('trisu', 'tri s security', 'Tri-S Security Corp')
# ('jor', 'earle m jorgensen', 'Earle M Jorgensen Co')
# ('1719848d', 'education', 'Education Realty Trust Inc')
# ('conr', 'conor medsystems', 'Conor Medsystems Inc')
# ('cvbt', 'venturis therapeutics', 'Venturis Therapeutics Inc')
# ('xlt', 'xl techgroup', 'XL TechGroup Inc')
# ('8230905q', 'alpha natural resource old', 'Alpha Natural Resource Inc/Old')
# ('foxh', 'foxhollow technologies', 'FoxHollow Technologies Inc')
# ('1922908d', 'great wolf resorts', 'Great Wolf Resorts Inc')
# ('usspq', 'shipping', 'US Shipping Corp')
# ('adza', 'cytyc prenatal products', 'Cytyc Prenatal Products Corp')
# ('kma', 'kmg america', 'KMG America Corp')
# ('2997709q', 'portalplayer', 'PortalPlayer LLC')
# ('tpqcz', 'trinity acquisition', 'Trinity Partners Acquisition Co Inc')
# ('suai', 'specialty underwriters alliance', "Specialty Underwriters' Alliance Inc")
# ('cabg', 'cabg medical', 'CABG Medical Inc')
# ('odmo', 'odimo', 'Odimo Inc')
# ('vlly', 'valley bancorp', 'Valley Bancorp')
# ('1429746d', 'xenith bankshares old', 'Xenith Bankshares Inc/old')
# ('phc', 'plant health care', 'Plant Health Care PLC')
# ('2102955d', 'gmh communities', 'GMH Communities Trust')
# ('snbt', 'snb bancshares tx', 'SNB Bancshares Inc/TX')
# ('1903510d', 'si', 'SI Financial Group Inc')
# ('ssag', 'ssa global technologies', 'SSA Global Technologies Inc')
# ('gkis', 'pilgrims pride georgia', "Pilgrim's Pride Corp of Georgia Inc")
# ('sax', 'saxon capital', 'Saxon Capital Inc')
# ('ggbmq', 'gigabeam', 'Gigabeam Corp')
# ('2279928q', 'global signal', 'Global Signal Inc')
# ('hmbnq', 'homebanc ga', 'HomeBanc Corp/GA')
# ('1556442d', 'gigpeak', 'GigPeak Inc')
# ('1440013d', 'cogent', 'Cogent Inc')
# ('clwa', 'callwave', 'CallWave Inc')
# ('ped/u', 'smartpros', 'SmartPros LLC')
# ('answ', 'answers', 'Answers.com Corp')
# ('hco/u', 'mpc', 'MPC Corp')
# ('1022664d', 'solar integrated technologies', 'Solar Integrated Technologies Inc')
# ('qcco', 'qc', 'QC Holdings Inc')
# ('2771627q', 'eagle hospitality properties', 'Eagle Hospitality Properties Trust Inc')
# ('nrph', 'new river pharmaceuticals', 'New River Pharmaceuticals Inc')
# ('1993649d', 'biomed', 'BioMed Realty Trust Inc')
# ('ecst', 'ecost', 'eCost.com Inc')
# ('1889180d', 'planetout', 'PlanetOut Inc')
# ('1023767d', 'northstar old', 'NorthStar Realty Finance Corp/old')
# ('cfsi', 'education services virginia', 'Education Services Co/Virginia')
# ('dry', 'coinmach service', 'Coinmach Service LLC')
# ('clrk', 'color kinetics', 'Color Kinetics Inc')
# ('mmrf', 'mmrglobal', 'MMRGlobal Inc')
# ('icgn', 'pfizer research nc', 'Pfizer Research NC Inc')
# ('1769019d', 'viacell', 'ViaCell Inc')
# ('ldis', 'leadis technology', 'Leadis Technology Inc')
# ('mhl', 'mortgageit', 'MortgageIT Holdings Inc')
# ('1709985d', 'chiesi usa', 'Chiesi USA Inc')
# ('mnkb', 'monadnock bancorp', 'Monadnock Bancorp Inc')
# ('bmnm', 'bimini capital management', 'Bimini Capital Management Inc')
# ('tbhs', 'bank', 'Bank Holdings/The')
# ('3449016q', 'adesa', 'ADESA Inc')
# ('mnta', 'momenta pharmaceuticals', 'Momenta Pharmaceuticals Inc')
# ('0561286d', 'cotherix', 'CoTherix Inc')
# ('1233306d', 'animas', 'Animas Corp')
# ('8251545q', 'atlas energy', 'Atlas Energy Inc')
# ('1898502d', 'origen', 'Origen Financial Inc')
# ('526356q', 'bancorp bank', 'Bancorp Bank/The')
# ('1373473d', 'metabasis therapeutics', 'Metabasis Therapeutics Inc')
# ('fmmh', 'fremont michigan insuracorp', 'Fremont Michigan InsuraCorp Inc')
# ('simpq', 'simply', 'Simply Inc')
# ('memy', 'memory pharmaceuticals', 'Memory Pharmaceuticals Corp')
# ('8222737q', 'nxp usa', 'NXP USA Inc')
# ('1699715d', 'osage bancshares', 'Osage Bancshares Inc')
# ('1523541d', 'simplicity bancorp', 'Simplicity Bancorp Inc')
# ('immcq', 'immunicon', 'Immunicon Corp')
# ('ansvq', 'anesiva', 'Anesiva Inc')
# ('entn', 'entorian technologies', 'Entorian Technologies Inc')
# ('2537769d', 'qualcomm atheros', 'Qualcomm Atheros Inc')
# ('2499886d', 'caplease', 'CapLease Inc')
# ('smbi', 'symbion tn', 'Symbion Inc/TN')
# ('ands', 'anadys pharmaceuticals', 'Anadys Pharmaceuticals Inc')
# ('0000492d', 'pioneer municipal equity income', 'Pioneer Municipal and Equity Income Trust')
# ('rnvs', 'renovis', 'Renovis Inc')
# ('629563q', 'cleveland cliffs steel', 'Cleveland-Cliffs Steel LLC')
# ('cycc', 'cyclacel pharmaceuticals', 'Cyclacel Pharmaceuticals Inc')
# ('capeq', 'cape fear bank', 'Cape Fear Bank Corp')
# ('0759976d', 'government properties', 'Government Properties Trust Inc')
# ('knta', 'kintera', 'Kintera Inc')
# ('msh', 'mei pharma', 'MEI Pharma Inc')
# ('3141817q', 'highland hospitality', 'Highland Hospitality Corp')
# ('nptt', 'nptest', 'NPTest Holding Corp')
# ('987444q', 'falcon investment', 'Falcon Financial Investment Trust')
# ('cfhi', 'coast', 'Coast Financial Holdings Inc')
# ('myog', 'myogen', 'Myogen Inc')
# ('agccq', 'anchor glass container', 'Anchor Glass Container Corp')
# ('1083273d', 'flatbush federal bancorp', 'Flatbush Federal Bancorp Inc')
# ('3339188q', 'pharmion', 'Pharmion Corp')
# ('ntmd', 'nitromed', 'NitroMed Inc')
# ('lumcq', 'luminent mortgage capital', 'Luminent Mortgage Capital Inc')
# ('1797629d', 'amgen rockville', 'Amgen Rockville Inc')
# ('chle', 'centennial specialty foods', 'Centennial Specialty Foods Corp')
# ('dnet', 'digitalnet', 'DigitalNet Holdings Inc')
# ('naxg', 'natural golf', 'Natural Golf Corp')
# ('gtopq', 'genitope', 'Genitope Corp')
# ('1990431d', 'liberty bell bank', 'Liberty Bell Bank')
# ('ksp', 'kirby offshore marine', 'Kirby Offshore Marine LLC')
# ('txtm', 'protext mobility', 'ProText Mobility Inc')
# ('vaphq', 'vaso active pharmaceuticals', 'Vaso Active Pharmaceuticals Inc')
# ('acus', 'acusphere', 'Acusphere Inc')
# ('rpfg', 'rainier pacific', 'Rainier Pacific Financial Group Inc')
# ('redeq', 'red envelope', 'Red Envelope Inc')
# ('knbt', 'knbt bancorp', 'KNBT Bancorp Inc')
# ('abnj', 'american bancorp new jersey', 'American Bancorp of New Jersey Inc')
# ('qmm/u', 'q international', 'Q Comm International Inc')
# ('cfbc', 'community first bancorp md', 'Community First Bancorp Inc/MD')
# ('cvp', 'centerplate', 'Centerplate Inc')
# ('2979130q', 'intervideo', 'Intervideo Inc')
# ('redl', 'redline performance products', 'Redline Performance Products Inc')
# ('ipmt', 'ipayment', 'iPayment Inc')
# ('iasg', 'integrated alarm services', 'Integrated Alarm Services Group Inc')
# ('olcb', 'ohio legacy', 'Ohio Legacy Corp')
# ('ccfc', 'ccsb', 'CCSB Financial Corp')
# ('ccbi', 'commercial capital bancorp', 'Commercial Capital Bancorp Inc')
# ('0818604d', 'bridge street', 'Bridge Street Financial Inc')
# ('bdcg', 'bonds', 'Bonds.Com Group Inc')
# ('1612850d', 'atlantic liberty', 'Atlantic Liberty Financial Corp')
# ('ctdbq', 'citadel broadcasting old', 'Citadel Broadcasting Corp/Old')
# ('synf', 'synergy', 'Synergy Financial Group Inc')
# ('980359q', 'windrose medical properties', 'Windrose Medical Properties Trust')
# ('1727038d', 'montana mills bread', 'Montana Mills Bread Co Inc')
# ('wrkc', 'window rock capital', 'Window Rock Capital Holdings Inc')
# ('bkrsq', 'bakers footwear', 'Bakers Footwear Group Inc')
# ('toneq', 'tierone', 'TierOne Corp')
# ('irgi', 'inveresk research', 'Inveresk Research Group Inc')
# ('lplhu', 'locateplus', 'LocatePLUS Holdings Corp')
# ('0746722d', 'pacific energy', 'Pacific Energy Partners LP')
# ('hbg', 'hub international', 'HUB International Ltd')
# ('1903130d', 'regal entertainment', 'Regal Entertainment Group')
# ('0565926d', 'future electronics', 'Future Electronics Corp')
# ('329552q', 'veridian united states', 'Veridian Corp/United States')
# ('2290052q', 'quinton cardiology systems', 'Quinton Cardiology Systems Inc')
# ('1667565d', 'lin media', 'LIN Media LLC')
# ('pcaf', 'printcafe software', 'Printcafe Software Inc')
# ('gahc', 'global arena', 'Global Arena Holding Inc')
# ('531621q', 'travelers property casualty', 'Travelers Property Casualty Corp')
# ('msnwq', 'hni holdco', 'HNI Holdco Inc')
# ('dovp', 'dov pharmaceutical', 'Dov Pharmaceutical Inc')
# ('2828664q', 'medsource technologies', 'MedSource Technologies Inc')
# ('0118185d', 'loews carolina', 'Loews Corp - Carolina Group')
# ('petc', 'petco animal supplies', 'Petco Animal Supplies Inc')
# ('onmdq', 'vertical health solutions', 'Vertical Health Solutions Inc')
# ('lqmt', 'liquidmetal technologies', 'Liquidmetal Technologies Inc')
# ('bdsiu', 'biodelivery sciences international', 'BioDelivery Sciences International Inc')
# ('nscn', 'netscreen technologies', 'NetScreen Technologies Inc')
# ('2565046d', 'fresenius kabi usa', 'Fresenius Kabi USA Inc')
# ('769210q', 'premcor', 'Premcor Inc')
# ('wcimq', 'wci communities old', 'WCI Communities Inc/Old')
# ('nsda', 'nassda', 'Nassda Corp')
# ('mdcvu', 'universal media', 'Universal Media Group Inc')
# ('djo', 'djo opco', 'DJO Opco Holdings Inc')
# ('nwbo', 'northwest biotherapeutics', 'Northwest Biotherapeutics Inc')
# ('0814801d', 'bruker axs', 'Bruker AXS Inc')
# ('mhlxu', 'carepayment technologies', 'CarePayment Technologies Inc')
# ('rmk', 'aramark old', 'ARAMARK Corp/Old')
# ('2982007q', 'therasense', 'TheraSense Inc')
# ('1618448d', 'alliance healthcare services', 'Alliance HealthCare Services Inc')
# ('bfun', 'bam entertainment', 'Bam! Entertainment Inc')
# ('hpla', 'hpl technologies', 'HPL Technologies Inc')
# ('1888902d', 'mercfuel', 'Mercfuel Inc')
# ('ulab', 'unilab', 'Unilab Corp')
# ('1321686d', 'wright medical', 'Wright Medical Group Inc')
# ('glyn', 'galyans trading', "Galyan's Trading Co LLC")
# ('brzzq', 'briazz', 'Briazz Inc')
# ('myk', 'mykrolis', 'Mykrolis Corp')
# ('bfnbq', 'beach first national bancshares', 'Beach First National Bancshares Inc')
# ('gegqq', 'global power equipment old', 'Global Power Equipment Group Inc/Old')
# ('ecpn', 'el capitan precious metals', 'El Capitan Precious Metals Inc')
# ('1482276d', 'fmc technologies', 'FMC Technologies Inc')
# ('0623514d', 'united surgical international', 'United Surgical Partners International Inc')
# ('1912203d', 'norway acquisition', 'Norway Acquisition Corp')
# ('torcq', 'torch offshore', 'Torch Offshore Inc')
# ('80825q', 'mps merchant services', 'MPS Merchant Services Inc')
# ('3527578q', 'agere systems', 'Agere Systems Inc')
# ('dncr', 'dynacare', 'Dynacare Inc')
# ('gmrrq', 'gener8 maritime old', 'Gener8 Maritime Inc/Old')
# ('wpsl', 'wp stewart', 'WP Stewart & Co Ltd')
# ('gmxrq', 'thunderbird resources equity', 'Thunderbird Resources Equity Inc')
# ('649848q', 'westport resources', 'Westport Resources Corp')
# ('3610748q', 'encore acquisition', 'Encore Acquisition Co')
# ('569665q', 'multilink technology', 'Multilink Technology Corp')
# ('opsw', 'opsware', 'Opsware Inc')
# ('whqa', 'w h energy services', 'W-H Energy Services LLC')
# ('1833548d', 'rni wind down', 'RNI Wind Down Corp')
# ('atpaq', 'atp oil gas united states', 'ATP Oil & Gas Corp/United States')
# ('plum', 'plumtree software', 'Plumtree Software Inc')
# ('1832555d', 'array biopharma', 'Array BioPharma Inc')
# ('kyph', 'kyphon americas', 'Kyphon Americas Inc')
# ('0911013d', 'specialty laboratories', 'Specialty Laboratories Inc')
# ('583429q', 'simplex solutions united states', 'Simplex Solutions Inc/United States')
# ('742603q', 'verisity', 'Verisity Ltd')
# ('ocpi', 'optical communication products', 'Optical Communication Products Inc')
# ('0355864q', 'aerogen', 'AeroGen Inc')
# ('3293866q', 'orion power', 'Orion Power Holdings Inc')
# ('revuq', 'education 1', 'Education Holdings 1 Inc')
# ('catz', 'computer access technology', 'Computer Access Technology Corp')
# ('8283846q', 'surebeam', 'Surebeam Corp')
# ('1861206d', 'logicvision', 'Logicvision Inc')
# ('bconq', 'bp fly', 'BP Fly Corp')
# ('erplq', 'energy old', 'Energy Partners Ltd/Old')
# ('0118440q', 'third wave technologies', 'Third Wave Technologies Inc')
# ('pubb', 'pacific union bank', 'Pacific Union Bank')
# ('lmne', 'luminent', 'Luminent Inc')
# ('synp', 'synplicity', 'Synplicity Inc')
# ('2573872d', 'devx energy', 'DevX Energy Inc')
# ('1542834d', 'aquacell technologies', 'Aquacell Technologies Inc')
# ('mirkq', 'mirant old', 'Mirant Corp/Old')
# ('nwpwq', 'newpower', 'NewPower Holdings Inc')
# ('enwv', 'endwave', 'Endwave Corp')
# ('9991111d', 'maxar technologies', 'Maxar Technologies Ltd')
# ('inmx', 'informax', 'Informax Inc')
# ('0120599d', 'eden bioscience', 'Eden Bioscience Corp')
# ('ascxz', 'advanced switching communications', 'Advanced Switching Communications Inc')
# ('173150q', 'equinix old', 'Equinix Inc/Old')
# ('descq', 'distributed energy systems', 'Distributed Energy Systems Corp')
# ('3042466q', 'chippac', 'ChipPAC Inc')
# ('omny', 'omnisky', 'OmniSky Corp')
# ('2237931q', 'medichem life sciences', 'Medichem Life Sciences Inc')
# ('0813137d', 'ribapharm', 'Ribapharm Inc')
# ('cod', 'chiles offshore', 'Chiles Offshore Inc')
# ('itxiq', 'integrated telecom express', 'Integrated Telecom Express Inc')
# ('avsr', 'avistar communications', 'Avistar Communications Corp')
# ('668718q', 'avantgo', 'Avantgo Inc')
# ('inrg', 'inrange technologies', 'Inrange Technologies Corp')
# ('vvvvq', 'viasource communications', 'ViaSource Communications Inc')
# ('mcdt', 'mcdata', 'McDATA Corp')
# ('crnm', 'curon medical', 'Curon Medical Inc')
# ('mcelq', 'millennium cell', 'Millennium Cell Inc')
# ('dddp', '3 dimensional pharmaceuticals', '3-Dimensional Pharmaceuticals Inc')
# ('1936438d', 'peco ii', 'PECO II Inc')
# ('1016061q', 'viewlocity', 'Viewlocity Inc')
# ('soap', 'soapstone networks', 'Soapstone Networks Inc')
# ('2576365d', 'pemstar', 'Pemstar Inc')
# ('vlct', 'valicert', 'ValiCert Inc')
# ('amev', 'applied molecular evolution', 'Applied Molecular Evolution Inc')
# ('bgptq', 'bearingpoint', 'BearingPoint Inc')
# ('1813314d', 'danisco california', 'Danisco US Inc/California')
# ('vina', 'vina technologies', 'Vina Technologies')
# ('bwng', 'broadwing', 'Broadwing Corp')
# ('1948550d', 'rita medical systems', 'Rita Medical Systems Inc')
# ('qti of', 'water intelligence', 'Water Intelligence PLC')
# ('723068q', 'blue martini software', 'Blue Martini Software Inc')
# ('cosn', 'cosine communications', 'CoSine Communications Inc')
# ('agnt', 'argonaut technologies', 'Argonaut Technologies Inc')
# ('iawk', 'iasiaworks', 'iAsiaWorks Inc')
# ('crio', 'corio', 'Corio Inc')
# ('gnsc', 'genaissance pharmaceuticals', 'Genaissance Pharmaceuticals Inc')
# ('spwx', 'speechworks international', 'SpeechWorks International Inc')
# ('exee', 'exe technologies', 'EXE Technologies Inc')
# ('cdwd', 'cloudward', 'Cloudward Inc')
# ('phst', 'pharsight', 'Pharsight Corp')
# ('erms', 'eroomsystem technologies', 'eRoomSystem Technologies Inc')
# ('dgen', 'deltagen', 'Deltagen Inc')
# ('sgsf', 'signalsoft', 'Signalsoft Corp')
# ('0820558d', 'talarian', 'Talarian Corp')
# ('502462q', 'docent', 'Docent Inc')
# ('hpow', 'h power', 'H Power Corp')
# ('lsbc', 'large scale biology', 'Large Scale Biology Corp')
# ('vast', 'livingston international technology services', 'Livingston International Technology Services Corp')
# ('3679840q', 'peoplepc', 'PeoplePC Inc')
# ('1530827d', 'tvia', 'Tvia Inc')
# ('webx', 'cisco webex', 'Cisco WebEx LLC')
# ('knvs', 'knova software', 'Knova Software Inc')
# ('vgnx', 'variagenics', 'Variagenics Inc')
# ('uopx', 'university phoenix online', 'University of Phoenix Online')
# ('flbc', 'finger lakes bancorp', 'Finger Lakes Bancorp Inc')
# ('ardi', 'road united states', '@Road Inc/United States')
# ('1389976d', 'cbct bancshares', 'CBCT Bancshares Inc')
# ('micu', 'vicuron pharmaceuticals', 'Vicuron Pharmaceuticals Inc')
# ('vrmlq', 'vermillion old', 'Vermillion Inc/Old')
# ('evlvq', 'evolve software', 'Evolve Software Inc')
# ('355676q', 'rosetta inpharmatics', 'Rosetta Inpharmatics LLC')
# ('2460344d', 'hgst technologies santa ana', 'HGST Technologies Santa Ana Inc')
# ('ilnd', 'interland old', 'Interland Inc/Old')
# ('1384851d', 'opnet technologies', 'OPNET Technologies Inc')
# ('3714927q', 'genomica', 'Genomica Corp')
# ('imny', 'revitas', 'Revitas Inc')
# ('rsnt', 'resonate', 'Resonate Inc')
# ('tnsiz', 'triton network systems', 'Triton Network Systems Inc')
# ('rptr', 'repeater technologies', 'Repeater Technologies Inc')
# ('agixq', 'atherogenics', 'Atherogenics Inc')
# ('0778324d', 'esperion therapeutics old', 'Esperion Therapeutics Inc/Old')
# ('exhs', 'exhaust technologies', 'Exhaust Technologies Inc')
# ('lxnt', 'lexent', 'Lexent Inc')
# ('rndc', 'raindance communications', 'Raindance Communications Inc')
# ('cvgp', 'convergent', 'Convergent Group Corp')
# ('ingnq', 'introgen therapeutics', 'Introgen Therapeutics Inc')
# ('380406q', 'pinnacor', 'Pinnacor Inc')
# ('lexr', 'lexar media', 'Lexar Media Inc')
# ('2065469d', 'mainspring', 'Mainspring Inc')
# ('futf', 'futurus services', 'Futurus Financial Services Inc')
# ('aolaq', 'america online latin america', 'America Online Latin America Inc')
# ('hbe', 'henry brothers electronics nj', 'Henry Brothers Electronics Inc/NJ')
# ('dvinq', 'divine', 'Divine Inc')
# ('gorxq', 'geopharma', 'GeoPharma Inc')
# ('jlic', 'jesup lamont', 'Jesup & Lamont Inc')
# ('ways', 'wave sync', 'Wave Sync Corp')
